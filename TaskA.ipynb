# %% [markdown]
# ## <center>COA Document Understanding: Task A
#
# <center>by Clayton Cohn

# %% [markdown]
# This Colab notebook is a response to the Specright mini project code challenge's Task A. Task A was described as follows:
#
# *In this mini project, you are challenged to build a data extraction solution that can efficiently extract a subset of COA fields from a single template from one supplier.*
#
# Subset of COA fields:<br>
# >● Product Description<br>
# >● Lot Number<br>
# >● Manufacture Date<br>
# >● Test Name<br>
# >● Test Results<br>
# >● Test Specification
#
# Deliverables:
# >● (Required) A Jupyter Notebook with a readme explanation on how we can run your code.<br>
# >● (Optional) A brief report in pdf format explaining the approaches, and results.

# %% [markdown]
# This solution is implemented using Google Colab. As such, the notebook must first be mounted to the user's Google Drive. This cell can (and should) be ignored if the user is running this script for his or her or their local file system.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Below is the constant ```HOME_PATH```. This must point to the folder that contains all of the single-supplier COA files. If there are any other files in the folder, the program will throw a runtime exception.

# %%
HOME_PATH = "drive/My Drive/Specright/Single_Suppliers_Docs/"

# %% [markdown]
# I utilized the [pdftotext](https://pypi.org/project/pdftotext/) PDF parser to convert the PDF files into workable text. To properly function, the package requires that the [poppler c++ interface](https://packages.debian.org/stretch/libpoppler-cpp-dev) be installed locally before pip is called to install the package.
#
# Since Colab runs in a linux enviornment, the ```apt-get install``` command was used to install the poppler interface prior to pip installing the pdftotext package.

# %%
# !sudo apt-get install libpoppler-cpp-dev
# !pip install pdftotext
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libpoppler-cpp-dev is already the newest version (0.62.0-2ubuntu2.12).
# 0 upgraded, 0 newly installed, 0 to remove and 15 not upgraded.
# Requirement already satisfied: pdftotext in /usr/local/lib/python3.6/dist-packages (2.1.5)

# %% [markdown]
# Once the pdftotext library was imported, I created a ```parseFile``` helper function to parse a given PDF file and extract the necessary data.
#
# The function extracts all of the information as strings, except for the tests. The tests are extracted as a 2d list, where the first item (```tests[0]```) represents the tests' labels, and the remaining items represent the individual tests and their corresponding results and annotations.
#
# The function is annotated inline.

# %%
import os
import pdftotext
import re

'''
Each of the test files had all of the pertinent information confined to
the first page except for one. As such, a check had to be
implemented to identify this edge condition. For new COA instances, the
below list will serve as a reference for which files need to have additional
pages read into the program.
'''
multi_page = ["coa-kaolin-clay-purple.pdf"]

def parseFile(dir, filename):
  with open(dir+filename, "rb") as f:
    pdf = pdftotext.PDF(f)

    # Each COA is separated into list of lines
    page = pdf[0].split('\n')

    # Check if our file has multiple pages
    if filename in multi_page:
      page += pdf[1].split('\n')

    # Variables created to hold the information extracted
    product_name = ""
    lot_numer = ""
    tests = []
    test_labels = []

    # These indices are used to identify where in the text the "tests" are
    begin_test = None
    test_label_ind = None
    end_test = None
    
    # Need to address COA instances with more than one page
    begin_test2 = None
    end_test2 = None

    # Text is read line by line
    for i in range(len(page)):

      # Whitespace is stripped for uniformity and readability
      page[i] = page[i].strip()

      '''
      Below is the logic used to extract the specific information.
      Manufacture date is not identified on the COAs, so it is not extracted.
      Lot number is extracted, but each COA has the same value for lot number.
      Parsing was based on strings that were common to all instances.
      '''
      if page[i].startswith("Product Name:"):
        product_name = page[i].split(":")[1].strip()
      elif page[i].startswith("Lot Number:"):
        lot_number = page[i].split(":")[1].strip()

        # Lot number truncated to NA for readability and identifiability
        if lot_number.lower().startswith("not available"):
          lot_number = "NA"

        '''
        The logic to identify the various tests required different
        "split words" due to a lack of uniformity.
        '''
      elif page[i].startswith("Expiration Date:") or \
        page[i].startswith("Shelf Life:"):
        test_label_ind = i + 1
        begin_test = i + 2
      elif page[i].startswith("The above data") or \
            page[i].startswith("All product characteristic") or \
            page[i].startswith("Disclaimer: This"):

        end_test = i

        # If we are only concerned with the first page, break
        if filename not in multi_page:
            break
      else:
        continue

    # Test labels were split on two or more spaces
    test_labels = re.split(r'\s{2,}', page[test_label_ind])

    '''
    These two edge cases needed special attention, as their tests' label
    structure differed from that of the others.
    '''
    if (filename == "coa-multi-herb-oily-skin.pdf"):
          test_labels = ["Analytical Tests", "Description", "Result"]
    if (filename == "coa-caprylyl-glycol-ethylhexylglycerin.pdf"):
          test_labels = ["Characteristics/Method", "Specificiations (min)", \
                         "Specifications (max)", "Result"]
          begin_test += 1

    # The first item in each COA's test list is the list of test labels 
    tests.append(test_labels)

    # Here we need to address the COAs with multiple pages
    if filename in multi_page:

      '''
      Multi-page instances must be addressed individually. This is not ideal,
      as any new COAs added to the dataset must be addressed with individual
      logic on a case-by-case basis. I would like to find an alternative means
      of doing this.
      '''
      if filename == "coa-kaolin-clay-purple.pdf":

        '''
        The below two lines are inefficient. I could have the search stop when
        I find the correct lines. I will circle back to this if I have 
        time, but for now I am okay with it, as the code only executes on one
        COA, so it will not be too computationally expensive.
        '''

        # These line identify start and end indexes for the tests on page 2
        begin_test2 = [num for num in range(len(page)) \
                       if page[num].startswith("Selenium")][0]
        end_test2 = [num for num in range(len(page)) \
                     if page[num].startswith("Total Coliforms")][0]

    '''
    Individual tests were split on two or more spaces and then appended
    to the 2d tests list.
    '''
    for i in range(begin_test, end_test):
      test = re.split(r'\s{2,}', page[i])
      if len(test) == len(test_labels):
        tests.append(test)

    # Again, if the COA length is > 1 page, we must extract tests from page 2
    if filename in multi_page:

      # Multi-page instances must be addressed individually
      if filename == "coa-kaolin-clay-purple.pdf":
        for i in range(begin_test2+2, end_test2 + 1):
          test = re.split(r'\s{2,}', page[i])
          if i == begin_test2+2:
            test = ["Selenium", test[0], test[1]]
          tests.append(test)

        '''
        This part is also inefficient and rather sloppy. There is an overlap
        that causes certain tests to be included twice, so the below code is
        a workaround to fix this. I will circle back to this as well if I have
        time; however, like the previous mention of inefficient code, this 
        inefficiency is confined to a single COA. My concern right now is 
        completing the assignment (both the code and the write-up), so I will 
        have to worry about the optimization later. 
        '''
        br = [i for i in range(len(tests)) \
              if tests[i][0].startswith("Phone")][0]
        for i in range(br, br+6):
          del tests[br]

    # The function returns the parsed PDF as a dictionary
    return {"product_name":product_name, "lot_number":lot_number, "tests":tests}

# %% [markdown]
# The below cell tests the ```parseFile``` function on one file before iterating through the entire directory. This cell was also used extensively for debugging and checking edge cases.

# %%
test_file = parseFile(HOME_PATH, "coa-kaolin-clay-purple.pdf")
print(test_file)
# Out:
# {'product_name': 'Kaolin Clay, Purple', 'lot_number': 'NA', 'tests': [['Property', 'Specification', 'Analysis'], ['Appearance', 'Powder', 'Pass'], ['Color', 'Prple', 'Pass'], ['Odor', 'Characteristic', 'Pass'], ['Granulometric distribution (medium', '15.00 µm MAX', '12.48 µm'], ['Organic Material', '2.00% MAX', '0.29%'], ['Loss for Dehydration', '4.00% MAX', '0.47%'], ['SiO2', '48-62%', '53.88%'], ['Fe2O3', '5.5-10.0%', '8.93%'], ['AI2O3', '15-26%', '21.59%'], ['Antimony', '<0.50 ppm', '0.15 ppm'], ['Arsenic', '<2 ppm', '<1.00 ppm'], ['Cadmium', '<0.10 ppm', '<0.01 ppm'], ['Chromium', '<28 ppm', '22.00 ppm'], ['Cobalt', '<2 ppm', '0.80 ppm'], ['Lanthanum', '<25 ppm', '17.50 ppm'], ['Lead', '<32 ppm', '28.00 ppm'], ['Mercury', '<1 ppm', '<0.01 ppm'], ['Nickel', '<3 ppm', '1.90 ppm'], ['Selenium', '<2 ppm', '<1.00 ppm'], ['Total Bacteria', '<100 CFU/g', 'Pass'], ['Mold & Yeast', '<10 CFU/g', 'Pass'], ['Staphylococcus aureus', 'Absent', 'Absent'], ['Pseudomonas aeruginosa', 'Absent', 'Absent'], ['Total Coliforms', 'Absent', 'Absent']]}

# %% [markdown]
# I created another helper function, ```getFiles```, to iterate through the directory containing all of the COAs and import, convert, and merge them into a single list.

# %%
def getFiles(d):
  files = []
  for fname in os.listdir(d):
    doc = parseFile(d, fname)
    files.append(doc)
  print("Returned {} files.".format(len(files)))
  return files

# %%
all_files = getFiles(HOME_PATH);
# Out:
# Returned 70 files.

# %% [markdown]
# This helper function was created to print all of the data in a readble manner. It as used solely for debuggind and visualiztion.

# %%
def printFiles(files):
  for d in files:
    for k, v in d.items():
      print("{}: {}".format(k, v))
    print()

# %% [markdown]
# It is recommended to keep the call to ```printFiles``` commented out when not in use in order to reduce the length of the notebook.

# %%
# printFiles(all_files)

# %% [markdown]
# List of COAs is then converted into Pandas DataFrame, where each COA is an instance. From here, we can apply an AI/ML algorithm to the COAs with minimal additional effort.

# %%
import pandas as pd

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

df = pd.DataFrame(all_files)
df.head(100)
# Out:
#                                                                      product_name  \
# 0                                                                  Clay Mask Base
# 1                                                           White Charcoal Powder
# 2                                                                          Kaolin
# 3                                                                 AHA Fruit Acids
# 4                                                                     Citric Acid
# 5                                                                   Glycolic Acid
# 6                                                                     Lactic Acid
# 7                                                                  Salicylic Acid
# 8                                                          Shea Butter Glycerides
# 9                                                             Polyglyceryl Oleate
# 10                                                                      Laureth-3
# 11                                                       Lecithin Powder, Organic
# 12                                                                     Oxybenzone
# 13                                                                   Coenzyme Q10
# 14                                                                 Lacto Ceramide
# 15                                                  Vitamin A Liposomes (retinol)
# 16                                                            Vitamin A Microcaps
# 17                                                     Baobab Protein, Hydrolyzed
# 18                                                                    Barley Quat
# 19                                                    Hydrolyzed Collagen Protein
# 20  Hydrolyzed Elastin Protein, Benzylalcohol, Potassium Sorbate, Sodium Benzoate
# 21                                                                Oat Amino Acids
# 22                                                           Palmitoyl Isoleucine
# 23                                                     Quinoa Protein, Hydrolyzed
# 24                                                                      Rice Quat
# 25                                                       Silk Protein, Hydrolyzed
# 26                                                              Soy-Rice Peptides
# 27                                                       Hydrolyzed Wheat Protein
# 28                                                           Chromium Oxide Green
# 29                                                               Iron Oxide Black
# 30                                                               Iron Oxide Brown
# 31                                                                Natural Gel-Wax
# 32                                                           Palmitoyl Isoleucine
# 33                                                         Tea Tree Essential Oil
# 34                                                            Caprylyl Glycol EHG
# 35                                                            Caprylic Acid Combo
# 36                                                              Honeysuckle Blend
# 37                                                     Potassium Sorbate (powder)
# 38                                                                   Citrus Combo
# 39                                                                    Sorbic Acid
# 40                                                   Radish Root Ferment Filtrate
# 41                                                                  Hexanediol CG
# 42                                                           AntiMicro Root Blend
# 43                                                           CreamMaker® Silicone
# 44                                                                  PEG-8 Beeswax
# 45                                                                Sorbitan Oleate
# 46                                                           Multi-Herb Oily Skin
# 47                                                                Red Kaolin Clay
# 48                                                                  Henna Extract
# 49                                                                   Dead Sea Mud
# 50                                                            Kaolin Clay, Purple
# 51                                                            Bismuth Oxychloride
# 52                                                             Glycol Stearate IP
# 53                                        Neroli Hydrosol, USDA Certified Organic
# 54                                                             Rose Essence Water
# 55                                 Lavender Essence Water, USDA Certified Organic
# 56                                                              Apple Fruit Water
# 57                                                          Cranberry Fruit Water
# 58                                                              Grape Fruit Water
# 59                                                         Peg 7 Glyceryl Cocoate
# 60                                                 PEG-40 Hydrogenated Castor Oil
# 61                                                                 Polysorbate 20
# 62                                                              Benzylalcohol-DHA
# 63                                                                     Paraben DU
# 64                                                              Phenoxyethanol-SA
# 65                                                                 DMDM Hydantoin
# 66                                                              Gluconolactone SB
# 67                                                             Phenylpropanol EHG
# 68                                                           Glycine-Benzoic Acid
# 69                                                                 Phenoxyethanol
#
#    lot_number  \
# 0          NA
# 1          NA
# 2          NA
# 3          NA
# 4          NA
# 5          NA
# 6          NA
# 7          NA
# 8          NA
# 9          NA
# 10         NA
# 11         NA
# 12         NA
# 13         NA
# 14         NA
# 15         NA
# 16         NA
# 17         NA
# 18         NA
# 19         NA
# 20         NA
# 21         NA
# 22         NA
# 23         NA
# 24         NA
# 25         NA
# 26         NA
# 27         NA
# 28         NA
# 29         NA
# 30         NA
# 31         NA
# 32         NA
# 33         NA
# 34         NA
# 35         NA
# 36         NA
# 37         NA
# 38         NA
# 39         NA
# 40         NA
# 41         NA
# 42         NA
# 43         NA
# 44         NA
# 45         NA
# 46         NA
# 47         NA
# 48         NA
# 49         NA
# 50         NA
# 51         NA
# 52         NA
# 53         NA
# 54         NA
# 55         NA
# 56         NA
# 57         NA
# 58         NA
# 59         NA
# 60         NA
# 61         NA
# 62         NA
# 63         NA
# 64         NA
# 65         NA
# 66         NA
# 67         NA
# 68         NA
# 69         NA
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                tests
# 0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     [[Specifications, Range, Results], [Appearance, Thick cream, Pass], [Color, Yellow to beige, Pass], [pH value, 5.0-6.5, Pass]]
# 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    [[Assay, Specification, Results], [Appearance, Fine powder, Pass], [Color, Black, Pass], [Odor (triangle test), To match standard, Pass], [Particle Size (Mesh), 95% through 3000 mesh, Pass], [Ash %, <4.0, 3.3], [Moisture %, <12.0, 5.9], [Specific Density (g/ml), 0.45-0.55, 0.51], [Heavy Metals (ppm), <20.0, Pass], [Arsenic (ppm), <3.0, 0.31], [Lead (ppm), <10.0, 0.59], [Mercury (ppm), <1.0, 0.03], [Germanium (ppm), <1.0, 0.015], [Microbials, <100cfu/g, Pass]]
# 2                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  [[Test, Reference, Analysis], [Identification, Conforms to USP, Meets requirements], [Description, Conforms to USP, Meets requirements], [Loss on ignition, Max. 15.%, 13.82%], [Acid solubles, Max. 2.0%, 0.64%], [Iron, Slt. Reddish tint, Slt. Tint], [Carbonate, No effervescence, Passes test], [Lead, Max. 10.0 ppm, Less than 10.0 ppm], [Microbial Limits, Conforms to USP, Passes test]]
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      [[Assay, Specification, Results], [Appearance, Pale Yellow, transparent, corresponds], [pH 1.2-2.5, 1.2-2.5, 1.8], [Specific Gravity @20°C, 1.245-1.280, 1.249 g/ml], [Lactic Acid, 29.0-35.5, 33.2 %], [Glycolic Acid, 14.0-16.5, 15.7 %], [Citric Acid, 2.2-3.1, 2.5 %], [Tartaric Acid, 0.9-1.5, 1.1 %], [Total aerobic mesophile plate count, Max 100 CFU/g, corresponds], [Yeast and Molds, Max 10 CFU/ml, corresponds]]
# 4                                                                                  [[Analytical Tests, Specifications, Results], [Characteristics, White crystalline powder, Conforms], [Water solubility, Very, Conforms], [Ethanol solubility, Freely 96%, Conforms], [Ether solubility, Sparingly, Conforms], [Assay, 99.7-100.3%, 99.79%], [Water, 0.00-0.50%, 0.06%], [Calcium, <=30.0, Conforms], [Heavy metals as lead, <=5.0mg/kg, Conforms], [Iron, <=3.00, Conforms], [Arsenic, <=1.0mg/kg, Conforms], [Mercury, <=0.5, Conforms], [Chloride, <=5.0, Conforms], [Lead, <=0.5mg/kg, Conforms], [Oxalic acid, <=100, Conforms], [Sulphate (100mg/kg), <=100, Conforms], [Sulphated Ash, <=0.05, Conforms], [Residue on ignition (USP/FCC), <=0.05%, Conforms], [Bulk Density, 400-1300, Conforms], [Particles on mesh 25 (0.71mm), 0.00-10.00, Conforms], [Particles through 0,20mm, 0.00-10.00, 6.11], [Particles on mesh 0,63mm, 0.00-10.00, 2.20], [Particles <mesh 100 (0,150mm), 0.00-10.00, conforms]]
# 5                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      [[Analytical Tests, Specification, Analysis], [Appearance, Transparent, slightly yellowish liquid, pass], [Odor, Like burnt sugar, pass], [pH Value at 25 C, 0.5-2.0, 2.0], [Acid, Total, 70.0 Minimum, 70], [Specific Gravity, 1.27, Pass], [Water, %, 30.0 Maximum, 30], [Formic Acid, mg/kg, 100.0 Maximum, 100], [Color (Gardner), 1.0 Maximum, 1.0], [Sodium Chloride, %, 0.1-0.5, 0.3]]
# 6                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   [[Analytical Tests, Specification, Analysis], [Appearance, Clear, water-white syrupy liquid, pass], [Odor, Characteristic, pass], [Color (Gardner), 50 Maximum, 17], [Assay, 88% Minimum, 88.1]]
# 7                                                                                                                                                                                                                                                                                                                                                                                                                                             [[Characteristic, Specifications, Results], [Chlorides, 0-0.0100, <0.0100], [Melting Range, 158-161°C, 160.4°C], [Identification, Pass, Pass], [Heavy Metals (as Pb), 0-20 ug/g, <20], [Loss on Drying, 0-0.500, 0.075], [Rsidue on ignition, 0-0.0500, 0.0176], [Sulphates, 0-0.020, <0.020], [Assay, 99.5-101.00, 99.98], [Related compounds, 0-0.200, 0.0578], [Phenol, 0-0.0100, <0.0010], [Other impurities, 0-0.0500, <0.0010], [4-Hydroxybenzoic Acid, 0-0.1000, 0.0292], [4-Hydroxyisophthalic Acid, 0-0.0500, 0.0286], [Sum of Impurities, 0-0.2000, 0.0578]]
# 8                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 [[Parameter, Results], [Color (Gardner), 4.0], [Acid Value (mg KOH/g), 1.16], [Saponification Value (meq/kg), 163.2], [pH (1%IPA:H20), 6.8], [Moisture (%), 0.20]]
# 9                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   [[Property, Specification Range, Result], [Appearance @ 77 Deg C, Amber Liquid, Pass], [Color (Gardner), 9.0 max, 3.0], [Acid Value, 4.0 max, 2.5], [Saponification Value, 140.0-150.0, 142.37]]
# 10                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    [[Analytical Tests, Specification, Analysis], [Appearance, Clear liquid (may haze when chilled), Pass], [Color, Amber, Pass], [Moisture, 1.0 Maximum, 0.10], [Hydroxyl Value, 165.0-175.0, 171.2], [Acid Value, 5.0-6.5, 5.5]]
# 11                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        [[Analytical Tests, Specifications, Results], [Moisture Content, %, 3.05], [Total Plate Count, cfu/gm, 3400], [Yeast & Mold, cfu/gm, <10]]
# 12                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          [[Analytical Tests, Results], [Assay, %(HPLC), 98.0 Min, Result: 99.7], [Appearance @25 degrees C, Pale Yellow Crystalline Powder], [Melting Point, Degrees C, 62.6-63.0], [UV Absorbance (E288), 630 Min, Result: 655], [Total Aerobic Count, 100 cfu/g Max. Result: 16.0], [Total Leaf Mold, 100 cfu/g Max. Result: 14.0], [Loss on Drying %, 0.50 Max, Result: 0.12]]
# 13                                                                                                                                                                                                                                                                                                                                                                                                                                                    [[Analytical Tests, Specification, Results], [Particle size, 30-130 nm, 82.5 nm], [Density, 1.120-1.160 g/ml, 1.1496 g/ml], [pH (5% aqu solution), 4.0-6.0, 5.0], [Consistency & Appearance, Liquid, viscous, conforms], [Odor, Characteristic, conforms], [Color, Orange, transparent, Conforms], [CoEnzyme Q10 Content (HPLC), 6.8-7.3%, 7.06%], [Bacteriology: Total CFU, Total germ count: <100 cfu/g, <10 cfu/g], [Yeast/Mould, <100/g, <100/g], [Pseudomonas Aeroguinosa, Negative, Negative in 1 g], [E. Coli/Enterococcen, Negative, Negative in 1 g]]
# 14                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             [[Parameters, Specifications, Results:], [Appearance, Yellowish, opalescent to slightly, Corresponds], [pH, 6.5-7.5, 6.7], [Relative Density, 1.080-1.120, 1.105], [Identigy by HPTLC, Characteristic chromatogram, Corresponds], [Total Aerobic Mesophile Plate Count, <100 cfu/ml, Corresponds], [Specified Microorganisms, Not detectable in one ml, Corresponds]]
# 15                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       [[Analytical Tests, Specification, Analysis], [Appearance (visual), Clear, yellow liquid, Pass], [Odor, Fresh, aromatic, Pass], [pH, 6.5-7.5, 6.9], [Particle Size (PCS), 300-500nm, 387], [Microbiological Status (total plate count), < 10 CFU/ml, Pass]]
# 16                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        [[Analytical Tests, Specifications, Results], [Appearance, Light yellow viscous liquid, conforms], [Density 20 @ 20°C, 0.800-1.200, 1.0], [pH, 4.5-6.5, 6.05], [Viscosity, Brook, 25°C RVT, 3000-9000, 4856], [Retinol Concentration, 0.900-1.200, 0.900]]
# 17                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       [[Property, Specification, Analysis], [Appearance (at room temp), Clear to slightly hazy, amber liquid*, Pass], [Odor, Characteristic, Pass], [Non-Volatile Matter (1g/1hr/105°C), 10.5% MIN, 12.0%], [pH (Direct @ 25°C), 4.0-5.0, 4.9], [Ash (@ 800°C), 2.5% MAX, 1.8%], [Nitrogen, Dumas, 0.3% MIN, 0.5%], [Total Aerobic Bacteria, <100 CFU/mL; no pathogens, Pass], [Mold & Yeast, <100 CFU/mL, Pass]]
# 18                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         [[Property, Specification, Analysis], [Appearance (at room temp), Clear to slighty hazy, amber liquid*, Pass], [Odor, Characteristic, slight, Pass], [Non-Volatile Matter, 22.0-26.0%, 23.9%], [pH (Direct @ 25°C), 4.5-5.5, 5.1], [Color (Gardner), 14.0 MAX, Pass], [Ash (@ 800°C), 3.0% MAX, 1.1%], [IP, 9.0 MIN, 11.0], [Total Aerobic Bacteria, <100 CFU/mL; No pathogens, Pass], [Mold & Yeast, <100 CFU/mL, Pass]]
# 19                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      [[Assay, Specification, Results], [Appearance @ 25°C, Off white powder, Pass], [Odor, Faint, Proteinacous, Pass], [pH (10% aqueous, 4.8-6.5, 5.7], [Ash (800 °C), %, 2.5 Maximum, 0.3], [% Nitrogen (Kjeldahl), 16.0 Minimum, >16.0], [Aerobic Plate Count, <100/g, <100], [Yeast & Mold, <100/g, <100/g], [Gram Negative Rods, <10/g, <10/g], [Color (Gardner) (10%, 12.0 Maximum, 5], [Total Solids, %, 93 Minimum, 95.4]]
# 20                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       [[Property, Specification, Result], [Appearance, Clear to slightly hazy, yellow liquid*, Complies], [Odor, Characteristic, slight, Complies], [Nonvolatile Matter (1g/1hr/105°C), 10% Min, 11.9%], [pH, Direct at 25°C, 4.5-5.5, 4.9], [Ash (800°C), 1.0% Maximum, 0.1%], [Nitrogen, Dumas, 1.5-1.8 %, 1.7%], [Total Aerobic Bacteria, <100 CFU/mL; No pathogens, Complies], [Mold and Yeast, <100 CFU/mL, Complies], [Color Gardner, 8 Maximum, Complies]]
# 21                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     [[Property, Specification, Analysis], [Appearance (at room temp), Clear to slightly hazy, pale yellow to amber liquid*, Pass], [Odor, Characteristic, Pass], [Non-Volatite Matter (1g/1hr/105°C), 17.0-24.0%, 18.6%], [pH (Direct @ 25°C), 4.0-5.0, 4.5], [Color (Gardner), 12.0 MAX, Pass], [Ash (@ 800°C), 2.0% MAX, 0.8%], [Total Aerobic Bacteria, <100 CFU/mL; no pathogens, Pass], [Yeasts & Molds, <100 CFU/mL, Pass]]
# 22                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     [[Analytical Tests, Specifications, Results], [Appearance, White powder to granulates, conforms], [Water (Karl Fischer), Max 1%, 0.1%], [Palmitoyl isoleucine content, Min 85.0%, 98.1 %], [Sulphated ash, Max 2.0%, 0.2%], [Free palmitic acid (dry basis), Max 10.%, 1.7%]]
# 23                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            [[Property, Specification, Analysis], [Appearance (at room temp), Clear to slightly hazy, amber liquid*, Complies], [Odor, Characteristic, Complies], [Non-Volatile Matter (1g/1hr/105°C), 20.0% MIN, 20.3%], [pH (Direct @25°C), 4.0-5.5, 4.8], [Ash (@800°C), 2.0% MAX, 0.9%], [Total Aerobic Bacteria, <100 CFU/mL; no pathogens present, Complies], [Mold & Yeast, <100 CFU/mL, Complies], [Diethanolamine, % wt, 0.50 MAX, 0.09]]
# 24                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  [[Property, Specification, Analysis], [Appearance (at room temp), Clear to slightly hazy, amber liquid*, Complies], [Odor, Characteristic, Complies], [Non-Volatile Matter, 21.0-25.0%, 23.2%], [Color (Gardner), 14.0 MAX, Complies], [pH Value (@ 25°C), 4.5-6.5, 5.2], [Isoionic Point, 9.0 MIN, 10.5], [Total Aerobic Bacteria, <100 CFU/mL; No pathogens, Complies], [Mold & Yeast, <100 CFU/mL, Complies]]
# 25                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 [[Analytical Tests, Specifications, Results], [Appearance at room temp, Clear amber liquid*, Complies], [Odor, Characteristic, Complies], [Non-volatile Matter, 8.0-14.0%, 11.3%], [pH, Direct @ 25°C, 4.0-5.5, 4.5], [Color, Gardner, 11.0 MAX, Complies], [Ash 800°C, 0.5% MAX, 0.1%], [Nitrogen, Dumas, 1.6-2.3%, 1.8%], [Total Aerobic Bacteria, <100 CFU/ml; no pathogens, Complies], [Mold & Yeast, <100 CFU/ml, Complies]]
# 26                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       [[Analytical Tests/Parameters, Specifications, Results], [Appearance (visual), Yellowish to amber, Corresponds], [pH (EP 2.2.3), 5.6-6.3, 5.3], [Relative density d20/20 (EP 2.2.5), 1.055-1.090, 1.076], [Refractive index n25 (EP 2.2.6), 1.366-1.370, 1.370], [Identity by TLC / ninhydrin, Characteristic, Corresponds], [Collagenase inhibitory activity, > 10 ColU / ml, Corresponds], [Inhibitor Activity (enzymatic assay,, >5 EIU/ml, Corresponds], [SOD Activity (photometric assay), >1000 ORU/ml, Corresponds]]
# 27                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            [[Property, Specification, Analysis], [Appearance (at room temperature), Clear, amber liquid*, Pass], [Odor, Characteristic, mild, Pass], [Non-Volatile Matter, 18.0-23.0%, 21.0%], [pH (Direct @ 25°C), 4.0-5.5, 4.8], [Ash (@ 800°C), 3.0% MAX, 0.8%], [Total Aerobic Bacteria, <100 CFU/mL; No pathogens, Pass], [Mold & Yeast, <100 CFU/mL, Pass]]
# 28                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              [[Analytical Tests, Specifications, Results], [8256-CieLab delta A, -1.000-1.000, 0.350], [8256-CieLab delta B, -1.000-1.000, -0.440], [8256-CieLab delta E, 0.000-1.400, 0.570], [8256-CieLab delta L, -1.000-1.000, 0.090], [8256 CieLab Strength, 95.000-105.000, 96.460], [8A36-Arsenic, 0.00-3.00ppm, <3.00ppm], [8A36-Lead, 0.00-20.00ppm, <20.00ppm], [8A36-Mercury, 0.00-1.00ppm, <1.00ppm]]
# 29                                                                                                                                                                                                                                                                                                                         [[Analytical Tests, Specifications, Results], [Water Soluble Matter, Not more than 1.0% by total dissolution, Conforms], [Arsenic, Not more than 3mg/kg by total dissolution, 1.00], [Barium, Not more than 50mg/kg by total dissolution, 5.00], [Cadmium, Not more than 5mg/kg by total dissolution, 1.00], [Chromium, Not more than 100mg/kg by total dissolution, 16.00], [Copper, Not more than 50mg/kg by total dissolution, 10.00], [Lead, Not more than 10mg/kg by total dissolution, 4.00], [Mercury, Not more than 1mg/kg by total dissolution, 0.20], [Nickel, Not more than 200mg/kg by total dissolution, 47.00], [Zinc, Not more than 100mg/kg by total dissolution, 21.00]]
# 30                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    [[Analytical Tests, Specifications, Results], [Water Solubility, Insoluble, Insoluble], [Arsenic (ppm), 0-3, NF], [Barium (ppm), 0-50, NF], [Cadmium (ppm), 0-5, NF], [Chromium (ppm), 0-50, 3.7], [Copper (ppm), 0-50, NF], [Lead (ppm), 0-10, NF], [Mercury (10-213) (ppm), 0-1, NF], [Nickel (ppm), 0-50, 21], [Zinc (ppm), 0-50, 20], [Cobalt (ppm), 0-30, 2], [Total Pathogens 10-123, <100 CFU/g, Pass]]
# 31                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       [[Analytical Tests, Specifications, Results], [Appearance @ 25°C, Off white gel-wax, Pass], [Cone Penetration @ 77°F, 200.000 – 240.000 DMM, 240.000 DMM], [Melt Point, 63–72°C, 68.300°C]]
# 32                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     [[Analytical Tests, Specifications, Results], [Appearance, White powder to granulates, conforms], [Water (Karl Fischer), Max 1%, 0.1%], [Palmitoyl isoleucine content, Min 85.0%, 98.1 %], [Sulphated ash, Max 2.0%, 0.2%], [Free palmitic acid (dry basis), Max 10.%, 1.7%]]
# 33                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               [[Property, Specification, Analysis], [Alpha-pinine, 1-6, 2.5], [Sabinene, Trace-3.5, 0.1], [Alpha-Terpinene, 5-13, 9.6], [Para-Cymene, 0.5-8, 2.3], [Limonene, 0.5-1.5, 0.9], [1,8-cineole, Trace-15, 2.5], [Gamma-Terpinene, 10-28, 21.0], [Terpinolene, 1.5-5, 3.5], [Terpinen-4-ol, 30-48, 41.1], [Alpha-Terpineol, 1.5-8, 2.8], [Aromadendrene, Trace-3, 1.4], [Ledene, Trace-3, 1.1], [Delta-Cadinene, Trace-3, 1.1], [Globulol, Trace-1, 0.2], [Viridiflorol, Trace-1, 0.2]]
# 34                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   [[Characteristics/Method, Specificiations (min), Specifications (max), Result], [Appearance, Color, Odor, n/a, n/a, Clear liquid], [Density at 20°C, g/ml, 0.929, 0.942, 0.936], [Refractive Index at 20°C, 1.442, 1.455, 1.449], [Color Index, Hazen, n/a, 100, 5], [Ethylhexylglycerin, 27.0%, 33.0%, 30.0%]]
# 35                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  [[Property, Specification, Analysis], [Appereance @ 25 C, Clear Liquid, Pass], [Color, Light Amber, Pass], [Odor, Mild, Pass], [Specific Gravity, 0.95-1.05, 0.98], [Refractive Index @22C, 1.440-1.450, 1.445]]
# 36                                                                                                                                                                                                                                                                                             [[Specification, Range, Results], [Physical Form, Liquid, Conforms], [Color, Clear Colorless Yellowish tint to, Conforms], [Odor, Faint Characteristics, Conforms], [Specific Gravity (20deg. C), 1.1200-1.3200, 1.2815], [Refractive Index (20 Deg. C), 1.300-1.450, 1.420], [pH(20 Deg. C)(100%Concentrate), 9.00-12.00, 10.26], [Carrier Menstrual (Vehicle) Water, 30.0-57.0%, 48.80%], [Water Solubility, Clearly hazy Soluble, Soluble], [Dry Residue( 160deg C/2hrs), 30-70%, 50%], [Preservation, None, Conforms], [Pesticide Content, None, Conforms], [Total Germs, <100Cfu/ml – Non-Pathogenic, Conforms], [Total Yeast/molds, <100cfu/ ml, Conforms], [Heavy Metals(Total)As,Pb,Hg, <0.005ppm, Conforms]]
# 37                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           [[Analytical Tests, Specifications/Limits, Results], [Identification A & B, Passes test, Passes test], [Assay (C6H7KO2), % on dry basis, 98.0-101.00%, 99.3%], [Alkalinity, Passes test (~1%), Passes test], [Acidity (as Sorbic Acid), Passes test (~1%), Passes test], [Loss on drying, 1.0% max, 0.3%], [Heavy metals, 0.001% (10ppm) max, Meet], [Lead, Pb, 2 ppm max, meet], [Arsenic (as As), 3 ppm max, Meet], [Appearance, White powder, meet]]
# 38                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   [[Analytical Tests, Specification, Analysis], [Appearance, Clear to light yellow, viscous liquid, Pass], [Odor, Slight citric odor, Pass], [pH Value (10% Aqueous Solution), 1.5-3.0, 2.32], [Solubility in Water, 100%, Pass]]
# 39                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     [[Analytical Tests, Specifications, Results], [Assay (2,4-hexadienoic acid), dry, 99.0-101.0%, 99.5%], [Melting point range, °C, 132.0-135.0°C, 133.0-134.1°C], [Residue on ignition, 0.20% MAX, 0.05%], [Heavy metals (as Pb) %, 10 ppm MAX, Pass], [Lead, Pb, 2 ppm MAX, Pass], [Moisture, 0.5% MAX, 0.2%]]
# ...
# 54                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         [[Property, Specification, Analysis], [Appearance, Clear liquid, Pass], [Color (Gardner), 6 MAX, 1], [Odor, Characteristic, Pass], [Specific Gravity, 0.995-1.010, 1.000], [Refractive Index, 1.3240-1.3440, 1.3393], [pH, 3.0-5.0, 3.9]]
# 55                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                [[Property, Specification, Analysis], [Appearance, Clear liquid, Pass], [Color (Gardner), 6 MAX, 1], [Odor, Characteristic, Pass], [Specific Gravity, 0.980-1.000, 0.991], [Refractive Index, 1.3240-1.3440, 1.3360], [pH, 3.0-5.0, 3.7], [Lead, <10 ppm, Pass], [Arsenic, <3 ppm, Pass], [Mercury, <1 ppm, Pass]]
# 56                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     [[Property, Specification, Analysis], [Appearance, Clear colorless to slightly cloudy liquid, Pass], [Odor, Characteristic, Pass], [Oxydo-Reduction Potential, ≤35, 23], [Acid Value, ≤0.20 mg KOH/g, 0.05 mg KOH/g], [Conductivity Test, ≤300 µS/cm, 42 µS/cm], [Sterility Test, Sterile, Pass], [Traceability - Origin of Fruits, Italy, Pass], [Traceability – Variety Used, Goldn Morgen or Stark, Pass], [Traceability – Date of Fruits Crop, -, 92018]]
# 57                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    [[Property, Specification, Analysis], [Appearance, Clear colorless liquid, Pass], [Odor, Characteristic, Pass], [Oxydo-Reduction Potential, ≤35, 31], [Acid Value, ≤0.20 mg KOH/g, 0.07 mg KOH/g], [Conductivity Test, ≤300 µS/cm, 80 µS/cm], [Sterility Test, Sterile, Pass]]
# 58                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                [[Property, Specification, Analysis], [Appearance, Clear colorless to slightly cloudy liquid, Pass], [Odor, Characteristic, Pass], [Oxydo-Reduction Potential, ≤35, 30], [Acid Value, ≤0.60 mg KOH/g, 0.04 mg KOH/g], [Conductivity Test, ≤300 µS/cm, 74 µS/cm], [Sterility Test, Sterile, Pass], [pH (Pure Product), 2.5-6.0, 4.5], [Traceability – Origin of Fruits, Italy, Pass], [Traceability – Variety Used, Muscat, Pass], [Traceability – Date of Fruits Crop, -, 102019]]
# 59                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                [[Parameter, Method, Limits, Value/Unit], [Dioxane, GM_0617_01, <=5, <=5/ppm], [Colour to Hazen, GM_0140_01, <=200, 47/hazen], [Ethylenoxide, GM_0616_01, <=1, <=1/ppm], [Saponification Value, GM_0030_01, 90,0-105,0, 92,4/mg KOH/g], [Iodine Value, GM_0040_05, <=5, 2,9/g l/100g], [Hydroxyl Value, GM_0020_01, 175,0-195,0, 180,5/mg KOH/g], [Acid Value, GM_0010_01, <=5,00, 0,78/mg KOH/g]]
# 60                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    [[Characteristic, Specifications, Results], [Appearance @25°C, Off white/yellow liquid, Pass], [Color (Gardner), 6.0 max, 0.3], [pH (3% aqueous), 5.5-7.0, 6.3], [Moisture, % (KF), 1.0 max, 0.23], [Acid Value, 3.0 max, 0.67], [Saponification Value, 60.0-67.0, 66.9], [Iodine Value, 2.0 max, 0.76], [Hydroxyl Value, 59.0-68.0, 64.3], [pH (10% aqueous), 6.0-7.0, 6.94]]
# 61                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    [[Characteristic, Specifications, Laboratory Values, Results], [*Color Gardner, 3 max, 1, pass], [Hydroxyl Value (mg KOH/1g sample), 96-108, 97.72, pass], [Water, 3.0% max, 2.43, pass], [Saponification Value (mg KOH/1g, 40-50, 45.30, pass], [IR (NEAT), TMS, pass, pass]]
# 62                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           [[Analytical Tests, Specification, Analysis (Method)], [Appearance @ 25°C, Clear light yellow liquid, Pass], [Dehydroacetic Acid, %, 7.5-8.5, 8.15], [Total Alcohol, %, 86.0-88.0, 86.85], [Specific Gravity @ 20°C, 1.07-1.08, 1.073]]
# 63                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              [[Property, Specification, Results], [APHA Color, <=100, 22], [% Nitrogen by combustion, 5.8-6.4, 6.4], [Specific Gravity @25ׄC, 1.1768-1.1876, 1.1840], [Total Solids, 43.5-46.5, 45.5], [% Residue on ignition (Ash), <=0.5, 0.1], [Appearance, Clear liquid to light yellow, Pass], [Identification, Pass, Pass]]
# 64                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             [[Property, Specifications, Analysis], [Appearance (25°C), Clear to light yellow liquid, Pass], [Color (APHA), <=200, 12], [Specific gravity (25°C), 1.0140-1.0240, 1.0204], [Phenoxyethanol (GC, W1506) %, 50.5-54.5, 52.5], [1,2 Octanediol (GC, W1506) %, 40.0-44.0, 41.5], [Acid Value (W1413), 25.0-37.5, 30.5]]
# 65                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           [[Property, Specification, Analysis], [Appearance @ 25°C, Clear liquid, Pass], [Water, %, 42.0-46.0, 45.7], [pH (as is), 6.5-7.5, 7.06], [Specific Gravity @ 25°C, 1.150-1.162, 1.154], [Color (APHA), 15 MAX, 5], [% Free HCHO, 2.0 MAX, 0.06], [$ Total HCHO, 17.0-19.0, 17.8], [Assay/Activity %, 53.0-58.0, 55.80]]
# 66                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              [[Analytical Tests, Specification, Results], [Appearance, Powder, Pass], [Color, White to Off-white, Pass], [Odor, Characteristic, Pass], [Loss on Drying (105oC – 1g – 1hr), 5.0% max., 1.4], [Solubility in Water, Soluble, Pass]]
# 67                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           [[Analytical Tests, Specification, Analysis], [Appearance, Clear liquid, Pass], [Ethylhexylglycerin, % content, 29-31, 30], [Phenylpropanol, % content, 69-71, 70], [Specific Gravity at 25o C, 0.95-1.05, 0.97], [Viscosity @ 25oC, cPs, 100 Max, 44]]
# 68                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           [[Property, Specification, Analysis], [Appearance, Flakes, Pass], [Odor, Characteristic, Pass], [Color, Off-White, Pass], [Color on Lovibond in 1" Cell, Y+R, 10.000 MAX, 0.800], [pH, 1% Solution @25°C, 2.500-3.500, 2.700], [Moisture Content, % by Mass, 5.000% MAX, 0.780%], [Melting Point, 90.000-95.000°C, 94.000°C], [Acid Value, 340.000-365.000 mg KOH/g, 354.000 mg KOH/g]]
# 69                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         [[Property, Specification, Analysis], [Appearance, Clear thin liquid, Pass], [Odor, Mild, Pass], [Color, Colorless, Pass], [Color on Lovibond in 5-1/4 Cell (Y + R), 0.5 MAX, 0.300], [pH 1% Solution, 5.500-7.00, 6.150], [Specific Gravity @ 20°C, 1.105-1.110, 1.107], [Refractive Index @ 20°C, 1.537-1.539, 1.539], [Moisture Content % by Mass, 0.200% MAX, 0.029%], [Assay (% by GC), 99.000% MAX, 99.966%], [Free Phenol, 150.000 ppm MAX, Pass]]

# %% [markdown]
# Because the tests were stored as nested lists, I created a helper function to retrieve them from a given instance. The function takes two arguments, the instance's row and the DataFrame, and returns the nested list of tests for that particular instance as a 2d NumPy array (with ```tests[0]``` representing the labels for the specified COA's tests).

# %%
import numpy as np

def getTests(t, df):
  series = df.iloc[t]
  return np.array(series["tests"])

# %%
test = getTests(0, df)
print(test)
# Out:
# [['Specifications' 'Range' 'Results']
#  ['Appearance' 'Thick cream' 'Pass']
#  ['Color' 'Yellow to beige' 'Pass']
#  ['pH value' '5.0-6.5' 'Pass']]
